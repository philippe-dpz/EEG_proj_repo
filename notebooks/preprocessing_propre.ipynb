# %%
import os
import numpy as np
import pandas as pd
import mne
from mne.preprocessing import EOGRegression
import matplotlib 
matplotlib.use('Qt5Agg')

# %%
base_dir = r'C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research'
raw_data_dir = os.path.join(base_dir, 'mne_raw_final')           
filtered_data_dir = os.path.join(base_dir, 'clean_final') 
regression_data_dir = os.path.join(base_dir, 'regression_final')  
epochs_data_dir = os.path.join(base_dir, 'epochs_final')                 
baseline_epochs_data_dir = os.path.join(base_dir, 'baseline_epochs_final')

# %% [markdown]
# On place les différents canaux présent dans notre situation experimentale: 3 canaux EEG, 3 canaux EOG, ainsi que les parametres indiqués dans la description des données ( sfreq et durée d'époch).

# %%
# EEG and EOG settings
sampling_freq = 250
channel_names = ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
channel_types = ['eeg', 'eeg', 'eeg', 'eog', 'eog', 'eog']
info = mne.create_info(ch_names=channel_names, sfreq=sampling_freq, ch_types=channel_types)
info.set_montage(mne.channels.make_standard_montage('standard_1020'))

event_id_mapping = {'Event_0': 0, 'Event_1': 1}

epoch_time_start, epoch_time_end = -0.2, 4

# %% [markdown]
# Combined_data contient tous les fichiers experimentaux bruts avec le type d'epoch associé (1 ou 0). On applique les données défini avant.

# %%
#transformation en format mne 
for file in os.listdir(os.path.join(base_dir, 'combined_data')):
    if file.endswith('.csv'):
        df = pd.read_csv(os.path.join(base_dir, 'combined_data', file))
        
        eeg_signals = df[['C3', 'Cz', 'C4']].values.T
        eog_signals = df[['EOG:ch01', 'EOG:ch02', 'EOG:ch03']].values.T
        combined_data = np.vstack([eeg_signals, eog_signals])

        raw = mne.io.RawArray(combined_data, info)
        events = np.array([[i, 0, df['EventType'].iloc[i]] for i in range(len(df)) if df['EventStart'].iloc[i] == 1])
        annotations = mne.Annotations(onset=events[:, 0] / sampling_freq, duration=[4] * len(events),
                                      description=[f"Event_{e}" for e in events[:, 2]], orig_time=None)
        raw.set_annotations(annotations)
        
        raw_file_path = os.path.join(raw_data_dir, f"{os.path.splitext(file)[0]}_raw.fif")
        raw.save(raw_file_path, overwrite=True)
        print(f"Processed and saved {file} to {raw_file_path}")
# Out:
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0101T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0101T_raw.fif
# [done]
# Processed and saved B0101T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0101T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=552452
#     Range : 0 ... 552451 =      0.000 ...  2209.804 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0102T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0102T_raw.fif
# [done]
# Processed and saved B0102T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0102T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=469011
#     Range : 0 ... 469010 =      0.000 ...  1876.040 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0103T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0103T_raw.fif
# [done]
# Processed and saved B0103T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0103T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0201T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0201T_raw.fif
# [done]
# Processed and saved B0201T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0201T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0202T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0202T_raw.fif
# [done]
# Processed and saved B0202T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0202T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=464155
#     Range : 0 ... 464154 =      0.000 ...  1856.616 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0203T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0203T_raw.fif
# [done]
# Processed and saved B0203T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0203T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0301T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0301T_raw.fif
# [done]
# Processed and saved B0301T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0301T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0302T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0302T_raw.fif
# [done]
# Processed and saved B0302T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0302T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=464675
#     Range : 0 ... 464674 =      0.000 ...  1858.696 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0303T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0303T_raw.fif
# [done]
# Processed and saved B0303T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0303T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0401T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0401T_raw.fif
# [done]
# Processed and saved B0401T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0401T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=696266
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0402T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0402T_raw.fif
# [done]
# Processed and saved B0402T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0402T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=468559
#     Range : 0 ... 468558 =      0.000 ...  1874.232 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0403T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0403T_raw.fif
# [done]
# Processed and saved B0403T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0403T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0501T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0501T_raw.fif
# [done]
# Processed and saved B0501T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0501T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=696266
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0502T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0502T_raw.fif
# [done]
# Processed and saved B0502T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0502T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=461875
#     Range : 0 ... 461874 =      0.000 ...  1847.496 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0503T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0503T_raw.fif
# [done]
# Processed and saved B0503T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0503T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0601T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0601T_raw.fif
# [done]
# Processed and saved B0601T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0601T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0602T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0602T_raw.fif
# [done]
# Processed and saved B0602T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0602T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=470391
#     Range : 0 ... 470390 =      0.000 ...  1881.560 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0603T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0603T_raw.fif
# [done]
# Processed and saved B0603T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0603T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0701T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0701T_raw.fif
# [done]
# Processed and saved B0701T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0701T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0702T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0702T_raw.fif
# [done]
# Processed and saved B0702T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0702T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=466727
#     Range : 0 ... 466726 =      0.000 ...  1866.904 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0703T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0703T_raw.fif
# [done]
# Processed and saved B0703T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0703T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=787729
#     Range : 0 ... 787728 =      0.000 ...  3150.912 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0801T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0801T_raw.fif
# [done]
# Processed and saved B0801T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0801T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0802T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0802T_raw.fif
# [done]
# Processed and saved B0802T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0802T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=474835
#     Range : 0 ... 474834 =      0.000 ...  1899.336 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0803T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0803T_raw.fif
# [done]
# Processed and saved B0803T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0803T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0901T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0901T_raw.fif
# [done]
# Processed and saved B0901T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0901T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=604803
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0902T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0902T_raw.fif
# [done]
# Processed and saved B0902T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0902T_raw.fif
# Creating RawArray with float64 data, n_channels=6, n_times=460731
#     Range : 0 ... 460730 =      0.000 ...  1842.920 secs
# Ready.
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0903T_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0903T_raw.fif
# [done]
# Processed and saved B0903T.csv to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0903T_raw.fif

# %% [markdown]
# visualisation brut

# %%
example_file = r"C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0101T_raw.fif"
raw = mne.io.read_raw_fif(example_file, preload=True)
raw.plot(duration=4, scalings='auto')
# Out:
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0101T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# <MNEBrowseFigure size 1916x1032 with 4 Axes>
# Channels marked as bad:
# none
# Channels marked as bad:
# none

# %% [markdown]
# Les signaux EEG doivent etre taités pour enlever le plus de bruit et d'artefacts possible on va donc les filtrer et utiliser les EOG pour enlever l'activité cerebrale des clignements des yeux:

# %%
#filtrage bande passante classique 
for file in os.listdir(raw_data_dir):
    if file.endswith('_raw.fif'):
        raw = mne.io.read_raw_fif(os.path.join(raw_data_dir, file), preload=True)

        raw.filter(l_freq=8., h_freq=30., fir_design='firwin')
        filtered_file_path = os.path.join(filtered_data_dir, file.replace('_raw.fif', 'filtered_raw.fif'))
        raw.save(filtered_file_path, overwrite=True)
        print(f"Saved filtered data: {file} to {filtered_file_path}")
# Out:
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0101T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0101Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0101Tfiltered_raw.fif
# [done]
# Saved filtered data: B0101T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0101Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0102T_raw.fif...
#     Range : 0 ... 552451 =      0.000 ...  2209.804 secs
# Ready.
# Reading 0 ... 552451  =      0.000 ...  2209.804 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0102Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0102Tfiltered_raw.fif
# [done]
# Saved filtered data: B0102T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0102Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0103T_raw.fif...
#     Range : 0 ... 469010 =      0.000 ...  1876.040 secs
# Ready.
# Reading 0 ... 469010  =      0.000 ...  1876.040 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0103Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0103Tfiltered_raw.fif
# [done]
# Saved filtered data: B0103T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0103Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0201T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0201Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0201Tfiltered_raw.fif
# [done]
# Saved filtered data: B0201T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0201Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0202T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0202Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0202Tfiltered_raw.fif
# [done]
# Saved filtered data: B0202T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0202Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0203T_raw.fif...
#     Range : 0 ... 464154 =      0.000 ...  1856.616 secs
# Ready.
# Reading 0 ... 464154  =      0.000 ...  1856.616 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0203Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0203Tfiltered_raw.fif
# [done]
# Saved filtered data: B0203T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0203Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0301T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0301Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0301Tfiltered_raw.fif
# [done]
# Saved filtered data: B0301T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0301Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0302T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0302Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0302Tfiltered_raw.fif
# [done]
# Saved filtered data: B0302T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0302Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0303T_raw.fif...
#     Range : 0 ... 464674 =      0.000 ...  1858.696 secs
# Ready.
# Reading 0 ... 464674  =      0.000 ...  1858.696 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0303Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0303Tfiltered_raw.fif
# [done]
# Saved filtered data: B0303T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0303Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0401T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0401Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0401Tfiltered_raw.fif
# [done]
# Saved filtered data: B0401T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0401Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0402T_raw.fif...
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0402Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0402Tfiltered_raw.fif
# [done]
# Saved filtered data: B0402T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0402Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0403T_raw.fif...
#     Range : 0 ... 468558 =      0.000 ...  1874.232 secs
# Ready.
# Reading 0 ... 468558  =      0.000 ...  1874.232 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0403Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0403Tfiltered_raw.fif
# [done]
# Saved filtered data: B0403T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0403Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0501T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0501Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0501Tfiltered_raw.fif
# [done]
# Saved filtered data: B0501T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0501Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0502T_raw.fif...
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0502Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0502Tfiltered_raw.fif
# [done]
# Saved filtered data: B0502T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0502Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0503T_raw.fif...
#     Range : 0 ... 461874 =      0.000 ...  1847.496 secs
# Ready.
# Reading 0 ... 461874  =      0.000 ...  1847.496 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0503Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0503Tfiltered_raw.fif
# [done]
# Saved filtered data: B0503T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0503Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0601T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0601Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0601Tfiltered_raw.fif
# [done]
# Saved filtered data: B0601T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0601Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0602T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0602Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0602Tfiltered_raw.fif
# [done]
# Saved filtered data: B0602T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0602Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0603T_raw.fif...
#     Range : 0 ... 470390 =      0.000 ...  1881.560 secs
# Ready.
# Reading 0 ... 470390  =      0.000 ...  1881.560 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0603Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0603Tfiltered_raw.fif
# [done]
# Saved filtered data: B0603T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0603Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0701T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0701Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0701Tfiltered_raw.fif
# [done]
# Saved filtered data: B0701T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0701Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0702T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0702Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0702Tfiltered_raw.fif
# [done]
# Saved filtered data: B0702T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0702Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0703T_raw.fif...
#     Range : 0 ... 466726 =      0.000 ...  1866.904 secs
# Ready.
# Reading 0 ... 466726  =      0.000 ...  1866.904 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0703Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0703Tfiltered_raw.fif
# [done]
# Saved filtered data: B0703T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0703Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0801T_raw.fif...
#     Range : 0 ... 787728 =      0.000 ...  3150.912 secs
# Ready.
# Reading 0 ... 787728  =      0.000 ...  3150.912 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0801Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0801Tfiltered_raw.fif
# [done]
# Saved filtered data: B0801T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0801Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0802T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0802Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0802Tfiltered_raw.fif
# [done]
# Saved filtered data: B0802T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0802Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0803T_raw.fif...
#     Range : 0 ... 474834 =      0.000 ...  1899.336 secs
# Ready.
# Reading 0 ... 474834  =      0.000 ...  1899.336 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0803Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0803Tfiltered_raw.fif
# [done]
# Saved filtered data: B0803T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0803Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0901T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0901Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0901Tfiltered_raw.fif
# [done]
# Saved filtered data: B0901T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0901Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0902T_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0902Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0902Tfiltered_raw.fif
# [done]
# Saved filtered data: B0902T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0902Tfiltered_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\mne_raw_final\B0903T_raw.fif...
#     Range : 0 ... 460730 =      0.000 ...  1842.920 secs
# Ready.
# Reading 0 ... 460730  =      0.000 ...  1842.920 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0903Tfiltered_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0903Tfiltered_raw.fif
# [done]
# Saved filtered data: B0903T_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0903Tfiltered_raw.fif

# %%
example_file = r"C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0101Tfiltered_raw.fif"
raw = mne.io.read_raw_fif(example_file, preload=True)
raw.plot(duration=4, scalings = 'auto')
# Out:
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0101Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# <MNEBrowseFigure size 1916x1032 with 4 Axes>

# %% [markdown]
# Pour éliminer les artéfacts liés aux mouvements oculaires (EOG) dans les signaux EEG, on utilise une méthode de régression. Cette technique ajuste les signaux EEG en utilisant les signaux EOG comme régressors pour éliminer les composantes de variance communes. On peut ensuite tester si le regressor de mne à fonctionner en observant la différence de corrélation.

# %%
for file in os.listdir(filtered_data_dir):
    if file.endswith('_raw.fif'):
        filtered_file_path = os.path.join(filtered_data_dir, file)

        raw = mne.io.read_raw_fif(filtered_file_path, preload=True)

        raw.set_eeg_reference('average', projection=True)

        eog_regressor = mne.preprocessing.EOGRegression(picks='eeg', picks_artifact='eog')
        eog_regressor.fit(raw)  # Apprentissage du modèle
        raw_cleaned = eog_regressor.apply(raw, copy=True)  # Nettoyage des données

        # Sauvegarde des données nettoyées
        cleaned_file_path = os.path.join(
            regression_data_dir, file.replace('_raw.fif', '_regressed_raw.fif')
        )
        raw_cleaned.save(cleaned_file_path, overwrite=True)
        print(f"Données nettoyées sauvegardées : {file} -> {cleaned_file_path}")
# Out:
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0101Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0101Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0101Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0101Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0101Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0102Tfiltered_raw.fif...
#     Range : 0 ... 552451 =      0.000 ...  2209.804 secs
# Ready.
# Reading 0 ... 552451  =      0.000 ...  2209.804 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0102Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0102Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0102Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0102Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0103Tfiltered_raw.fif...
#     Range : 0 ... 469010 =      0.000 ...  1876.040 secs
# Ready.
# Reading 0 ... 469010  =      0.000 ...  1876.040 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0103Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0103Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0103Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0103Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0201Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0201Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0201Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0201Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0201Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0202Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0202Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0202Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0202Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0202Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0203Tfiltered_raw.fif...
#     Range : 0 ... 464154 =      0.000 ...  1856.616 secs
# Ready.
# Reading 0 ... 464154  =      0.000 ...  1856.616 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0203Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0203Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0203Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0203Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0301Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0301Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0301Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0301Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0301Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0302Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0302Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0302Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0302Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0302Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0303Tfiltered_raw.fif...
#     Range : 0 ... 464674 =      0.000 ...  1858.696 secs
# Ready.
# Reading 0 ... 464674  =      0.000 ...  1858.696 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0303Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0303Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0303Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0303Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0401Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0401Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0401Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0401Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0401Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0402Tfiltered_raw.fif...
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0402Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0402Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0402Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0402Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0403Tfiltered_raw.fif...
#     Range : 0 ... 468558 =      0.000 ...  1874.232 secs
# Ready.
# Reading 0 ... 468558  =      0.000 ...  1874.232 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0403Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0403Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0403Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0403Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0501Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0501Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0501Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0501Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0501Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0502Tfiltered_raw.fif...
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0502Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0502Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0502Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0502Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0503Tfiltered_raw.fif...
#     Range : 0 ... 461874 =      0.000 ...  1847.496 secs
# Ready.
# Reading 0 ... 461874  =      0.000 ...  1847.496 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0503Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0503Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0503Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0503Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0601Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0601Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0601Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0601Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0601Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0602Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0602Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0602Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0602Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0602Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0603Tfiltered_raw.fif...
#     Range : 0 ... 470390 =      0.000 ...  1881.560 secs
# Ready.
# Reading 0 ... 470390  =      0.000 ...  1881.560 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0603Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0603Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0603Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0603Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0701Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0701Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0701Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0701Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0701Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0702Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0702Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0702Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0702Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0702Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0703Tfiltered_raw.fif...
#     Range : 0 ... 466726 =      0.000 ...  1866.904 secs
# Ready.
# Reading 0 ... 466726  =      0.000 ...  1866.904 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0703Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0703Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0703Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0703Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0801Tfiltered_raw.fif...
#     Range : 0 ... 787728 =      0.000 ...  3150.912 secs
# Ready.
# Reading 0 ... 787728  =      0.000 ...  3150.912 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0801Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0801Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0801Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0801Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0802Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0802Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0802Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0802Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0802Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0803Tfiltered_raw.fif...
#     Range : 0 ... 474834 =      0.000 ...  1899.336 secs
# Ready.
# Reading 0 ... 474834  =      0.000 ...  1899.336 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0803Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0803Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0803Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0803Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0901Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0901Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0901Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0901Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0901Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0902Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0902Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0902Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0902Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0902Tfiltered_regressed_raw.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0903Tfiltered_raw.fif...
#     Range : 0 ... 460730 =      0.000 ...  1842.920 secs
# Ready.
# Reading 0 ... 460730  =      0.000 ...  1842.920 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Overwriting existing file.
# Writing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0903Tfiltered_regressed_raw.fif
# Closing C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0903Tfiltered_regressed_raw.fif
# [done]
# Données nettoyées sauvegardées : B0903Tfiltered_raw.fif -> C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0903Tfiltered_regressed_raw.fif

# %% [markdown]
# verification du bon fonctionnement de la regression : baisse de correlation entre eeg et eog, conservation de tout les échantillions.

# %%
example_file = r"C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0101Tfiltered_regressed_raw.fif"
raw = mne.io.read_raw_fif(example_file, preload=True)
raw.plot(duration=4, scalings = 'auto')
# Out:
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0101Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# <MNEBrowseFigure size 1916x1032 with 4 Axes>

# %%
for file in os.listdir(filtered_data_dir):
    if file.endswith('_raw.fif'):
        filtered_file_path = os.path.join(filtered_data_dir, file)
        raw_filtered = mne.io.read_raw_fif(filtered_file_path, preload=True)

        print(f"Canaux dans {file} avant régression :")
        print(raw_filtered.info['ch_names'])  

        # Trouver le fichier nettoyé correspondant
        regressed_file_path = os.path.join(regression_data_dir, file.replace('_raw.fif', '_regressed_raw.fif'))

        if os.path.exists(regressed_file_path):
            raw_regressed = mne.io.read_raw_fif(regressed_file_path, preload=True)

            print(f"Canaux dans {file} après régression :")
            print(raw_regressed.info['ch_names'])  

            eeg_filtered_data = raw_filtered.copy().pick_types(eeg=True).get_data()
            eeg_regressed_data = raw_regressed.copy().pick_types(eeg=True).get_data()

            len_filtered = eeg_filtered_data.shape[1]
            len_regressed = eeg_regressed_data.shape[1]
            length_diff = len_filtered - len_regressed 

            eog_filtered_data = raw_filtered.copy().pick_types(eog=True).get_data()
            eog_regressed_data = raw_regressed.copy().pick_types(eog=True).get_data()

            min_len = min(eeg_filtered_data.shape[1], eeg_regressed_data.shape[1], eog_filtered_data.shape[1])

            eeg_filtered_data = eeg_filtered_data[:, :min_len]
            eeg_regressed_data = eeg_regressed_data[:, :min_len]
            eog_filtered_data = eog_filtered_data[:, :min_len]

            corr_before = np.corrcoef(eeg_filtered_data.flatten(), eog_filtered_data.flatten())[0, 1]

            corr_after = np.corrcoef(eeg_regressed_data.flatten(), eog_regressed_data.flatten())[0, 1]


            print(f"Fichier : {file}")
            print(f"Différence de longueur (avant - après) : {length_diff}")
            print(f"Corrélation EEG-EOG avant nettoyage : {corr_before:.4f}")
            print(f"Corrélation EEG-EOG après nettoyage : {corr_after:.4f}")
# Out:
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0101Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0101Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0101Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0101Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0101Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0415
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0102Tfiltered_raw.fif...
#     Range : 0 ... 552451 =      0.000 ...  2209.804 secs
# Ready.
# Reading 0 ... 552451  =      0.000 ...  2209.804 secs...
# Canaux dans B0102Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0102Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 552451 =      0.000 ...  2209.804 secs
# Ready.
# Reading 0 ... 552451  =      0.000 ...  2209.804 secs...
# Canaux dans B0102Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0102Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0374
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0103Tfiltered_raw.fif...
#     Range : 0 ... 469010 =      0.000 ...  1876.040 secs
# Ready.
# Reading 0 ... 469010  =      0.000 ...  1876.040 secs...
# Canaux dans B0103Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0103Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 469010 =      0.000 ...  1876.040 secs
# Ready.
# Reading 0 ... 469010  =      0.000 ...  1876.040 secs...
# Canaux dans B0103Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0103Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0277
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0201Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0201Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0201Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0201Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0201Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0599
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0202Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0202Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0202Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0202Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0202Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0645
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0203Tfiltered_raw.fif...
#     Range : 0 ... 464154 =      0.000 ...  1856.616 secs
# Ready.
# Reading 0 ... 464154  =      0.000 ...  1856.616 secs...
# Canaux dans B0203Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0203Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 464154 =      0.000 ...  1856.616 secs
# Ready.
# Reading 0 ... 464154  =      0.000 ...  1856.616 secs...
# Canaux dans B0203Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0203Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0435
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0301Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0301Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0301Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0301Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0301Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0439
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0302Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0302Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0302Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0302Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0302Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0419
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0303Tfiltered_raw.fif...
#     Range : 0 ... 464674 =      0.000 ...  1858.696 secs
# Ready.
# Reading 0 ... 464674  =      0.000 ...  1858.696 secs...
# Canaux dans B0303Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0303Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 464674 =      0.000 ...  1858.696 secs
# Ready.
# Reading 0 ... 464674  =      0.000 ...  1858.696 secs...
# Canaux dans B0303Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0303Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0321
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0401Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0401Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0401Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0401Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0401Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0574
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0402Tfiltered_raw.fif...
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# Canaux dans B0402Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0402Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# Canaux dans B0402Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0402Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0406
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0403Tfiltered_raw.fif...
#     Range : 0 ... 468558 =      0.000 ...  1874.232 secs
# Ready.
# Reading 0 ... 468558  =      0.000 ...  1874.232 secs...
# Canaux dans B0403Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0403Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 468558 =      0.000 ...  1874.232 secs
# Ready.
# Reading 0 ... 468558  =      0.000 ...  1874.232 secs...
# Canaux dans B0403Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0403Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0368
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0501Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0501Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0501Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0501Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0501Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0573
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0502Tfiltered_raw.fif...
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# Canaux dans B0502Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0502Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# Canaux dans B0502Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0502Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0685
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0503Tfiltered_raw.fif...
#     Range : 0 ... 461874 =      0.000 ...  1847.496 secs
# Ready.
# Reading 0 ... 461874  =      0.000 ...  1847.496 secs...
# Canaux dans B0503Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0503Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 461874 =      0.000 ...  1847.496 secs
# Ready.
# Reading 0 ... 461874  =      0.000 ...  1847.496 secs...
# Canaux dans B0503Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0503Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0463
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0601Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0601Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0601Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0601Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0601Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0381
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0602Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0602Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0602Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0602Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0602Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0333
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0603Tfiltered_raw.fif...
#     Range : 0 ... 470390 =      0.000 ...  1881.560 secs
# Ready.
# Reading 0 ... 470390  =      0.000 ...  1881.560 secs...
# Canaux dans B0603Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0603Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 470390 =      0.000 ...  1881.560 secs
# Ready.
# Reading 0 ... 470390  =      0.000 ...  1881.560 secs...
# Canaux dans B0603Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0603Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0265
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0701Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0701Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0701Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0701Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0701Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0706
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0702Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0702Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0702Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0702Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0702Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0688
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0703Tfiltered_raw.fif...
#     Range : 0 ... 466726 =      0.000 ...  1866.904 secs
# Ready.
# Reading 0 ... 466726  =      0.000 ...  1866.904 secs...
# Canaux dans B0703Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0703Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 466726 =      0.000 ...  1866.904 secs
# Ready.
# Reading 0 ... 466726  =      0.000 ...  1866.904 secs...
# Canaux dans B0703Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0703Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0510
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0801Tfiltered_raw.fif...
#     Range : 0 ... 787728 =      0.000 ...  3150.912 secs
# Ready.
# Reading 0 ... 787728  =      0.000 ...  3150.912 secs...
# Canaux dans B0801Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0801Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 787728 =      0.000 ...  3150.912 secs
# Ready.
# Reading 0 ... 787728  =      0.000 ...  3150.912 secs...
# Canaux dans B0801Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0801Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0513
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0802Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0802Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0802Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0802Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0802Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0464
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0803Tfiltered_raw.fif...
#     Range : 0 ... 474834 =      0.000 ...  1899.336 secs
# Ready.
# Reading 0 ... 474834  =      0.000 ...  1899.336 secs...
# Canaux dans B0803Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0803Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 474834 =      0.000 ...  1899.336 secs
# Ready.
# Reading 0 ... 474834  =      0.000 ...  1899.336 secs...
# Canaux dans B0803Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0803Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0426
# Corrélation EEG-EOG après nettoyage : 0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0901Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0901Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0901Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0901Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0901Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0628
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0902Tfiltered_raw.fif...
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0902Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0902Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Canaux dans B0902Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0902Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0497
# Corrélation EEG-EOG après nettoyage : -0.0000
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\clean_final\B0903Tfiltered_raw.fif...
#     Range : 0 ... 460730 =      0.000 ...  1842.920 secs
# Ready.
# Reading 0 ... 460730  =      0.000 ...  1842.920 secs...
# Canaux dans B0903Tfiltered_raw.fif avant régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0903Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 460730 =      0.000 ...  1842.920 secs
# Ready.
# Reading 0 ... 460730  =      0.000 ...  1842.920 secs...
# Canaux dans B0903Tfiltered_raw.fif après régression :
# ['C3', 'Cz', 'C4', 'EOG:ch01', 'EOG:ch02', 'EOG:ch03']
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Removing projector <Projection | Average EEG reference, active : True, n_channels : 3>
# Fichier : B0903Tfiltered_raw.fif
# Différence de longueur (avant - après) : 0
# Corrélation EEG-EOG avant nettoyage : 0.0353
# Corrélation EEG-EOG après nettoyage : -0.0000

# %%
#decoupage en epoch
for file in os.listdir(regression_data_dir):
    if file.endswith('raw.fif'):
        raw = mne.io.read_raw_fif(os.path.join(regression_data_dir, file), preload=True)
        
        try:
            events, _ = mne.events_from_annotations(raw, event_id=event_id_mapping)
        except ValueError as e:
            print(f"Error extracting events for {file}: {e}")
            continue
        
        epochs = mne.Epochs(raw, events, event_id=event_id_mapping, tmin=epoch_time_start, tmax=epoch_time_end,
                            baseline=None, detrend=1, preload=True)
        
        epochs_file_path = os.path.join(epochs_data_dir, file.replace('filtered_regressed_raw.fif', '-epo.fif'))
        epochs.save(epochs_file_path, overwrite=True)
        print(f"Saved epochs for {file} to {epochs_file_path}")
# Out:
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0101Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0101Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0101T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0102Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 552451 =      0.000 ...  2209.804 secs
# Ready.
# Reading 0 ... 552451  =      0.000 ...  2209.804 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0102Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0102T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0103Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 469010 =      0.000 ...  1876.040 secs
# Ready.
# Reading 0 ... 469010  =      0.000 ...  1876.040 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 160 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0103Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0103T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0201Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0201Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0201T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0202Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0202Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0202T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0203Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 464154 =      0.000 ...  1856.616 secs
# Ready.
# Reading 0 ... 464154  =      0.000 ...  1856.616 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 160 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0203Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0203T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0301Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0301Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0301T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0302Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0302Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0302T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0303Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 464674 =      0.000 ...  1858.696 secs
# Ready.
# Reading 0 ... 464674  =      0.000 ...  1858.696 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 160 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0303Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0303T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0401Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0401Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0401T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0402Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 140 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0402Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0402T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0403Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 468558 =      0.000 ...  1874.232 secs
# Ready.
# Reading 0 ... 468558  =      0.000 ...  1874.232 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 160 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0403Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0403T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0501Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0501Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0501T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0502Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 696265 =      0.000 ...  2785.060 secs
# Ready.
# Reading 0 ... 696265  =      0.000 ...  2785.060 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 140 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0502Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0502T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0503Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 461874 =      0.000 ...  1847.496 secs
# Ready.
# Reading 0 ... 461874  =      0.000 ...  1847.496 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 160 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0503Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0503T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0601Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0601Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0601T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0602Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0602Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0602T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0603Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 470390 =      0.000 ...  1881.560 secs
# Ready.
# Reading 0 ... 470390  =      0.000 ...  1881.560 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 160 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0603Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0603T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0701Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0701Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0701T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0702Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0702Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0702T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0703Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 466726 =      0.000 ...  1866.904 secs
# Ready.
# Reading 0 ... 466726  =      0.000 ...  1866.904 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 160 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0703Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0703T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0801Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 787728 =      0.000 ...  3150.912 secs
# Ready.
# Reading 0 ... 787728  =      0.000 ...  3150.912 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 160 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0801Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0801T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0802Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0802Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0802T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0803Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 474834 =      0.000 ...  1899.336 secs
# Ready.
# Reading 0 ... 474834  =      0.000 ...  1899.336 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 160 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0803Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0803T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0901Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0901Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0901T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0902Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 604802 =      0.000 ...  2419.208 secs
# Ready.
# Reading 0 ... 604802  =      0.000 ...  2419.208 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 120 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0902Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0902T-epo.fif
# Opening raw data file C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\regression_final\B0903Tfiltered_regressed_raw.fif...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Range : 0 ... 460730 =      0.000 ...  1842.920 secs
# Ready.
# Reading 0 ... 460730  =      0.000 ...  1842.920 secs...
# Used Annotations descriptions: ['Event_0', 'Event_1']
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 160 events and 1051 original time points ...
# 0 bad epochs dropped
# Overwriting existing file.
# Overwriting existing file.
# Saved epochs for B0903Tfiltered_regressed_raw.fif to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0903T-epo.fif

# %% [markdown]
# On applique une correction baseline : la baseline est une periode de temps ou le signal et considéré comme stable pour qu'on puisse prendre cette partie de signal en réference. Cela nous permet en théorie d'amplifier l'activité spécifique due à l'evemenent. On prend comme baseline pour chaque epoch la periode 0.2 secondes post evenement, on sait qu'il y à au moins une seconde de repos (stable) après chaque evenement et c'est un standard dans le preprocessing de signal eeg.

# %%
baseline_start = -0.2  
baseline_end = 0.0


for file in os.listdir(epochs_data_dir):
    if file.endswith('-epo.fif'):
        epochs = mne.read_epochs(os.path.join(epochs_data_dir, file))

        epochs.apply_baseline(baseline=(baseline_start, baseline_end))

        baseline_epochs_file_path = os.path.join(baseline_epochs_data_dir, file.replace('-epo.fif', '-bcor-epo.fif'))
        epochs.save(baseline_epochs_file_path, overwrite=True)

        print(f"Baseline-corrected and cropped epochs saved: {baseline_epochs_file_path}")
# Out:
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0101T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0101T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0102T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0102T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0103T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0103T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0201T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0201T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0202T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0202T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0203T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0203T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0301T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0301T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0302T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0302T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0303T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0303T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0401T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0401T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0402T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0402T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0403T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0403T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0501T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0501T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0502T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0502T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0503T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0503T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0601T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0601T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0602T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0602T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0603T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0603T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0701T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0701T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0702T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0702T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0703T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0703T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0801T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0801T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0802T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0802T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0803T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0803T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0901T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0901T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0902T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0902T-bcor-epo.fif
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\epochs_final\B0903T-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Applying baseline correction (mode: mean)
# Overwriting existing file.
# Overwriting existing file.
# Baseline-corrected and cropped epochs saved: C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0903T-bcor-epo.fif

# %%
# Iterate through each file in the baseline epochs directory
for file in os.listdir(baseline_epochs_data_dir):
    if file.endswith('-epo.fif'):  # Check only .fif files containing epochs
        file_path = os.path.join(baseline_epochs_data_dir, file)
        
        # Read the epochs from the file
        epochs = mne.read_epochs(file_path)
        
        # Check the time points of the first few epochs
        for i, epoch in enumerate(epochs.get_data()):
            # Print out the times for the first few epochs to verify
            print(f"Epoch {i+1} in {file} time range: {epochs.times[0]} to {epochs.times[-1]}")
            print(f"Epoch {i+1} in {file} times: {epochs.times[:10]} ...")  # First 10 time points
# Out:
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0101T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =       0.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Epoch 1 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 1 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 2 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 2 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 3 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 3 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 4 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 4 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 5 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 5 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 6 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 6 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 7 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 7 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 8 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 8 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 9 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 9 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 10 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 10 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 11 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 11 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 12 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 12 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 13 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 13 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 14 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 14 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 15 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 15 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 16 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 16 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 17 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 17 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 18 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 18 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 19 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 19 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 20 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 20 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 21 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 21 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 22 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 22 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 23 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 23 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 24 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 24 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 25 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 25 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 26 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 26 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 27 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 27 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 28 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 28 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 29 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 29 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 30 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 30 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 31 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 31 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 32 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 32 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 33 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 33 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 34 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 34 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 35 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 35 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 36 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 36 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 37 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 37 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 38 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 38 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 39 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 39 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 40 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 40 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 41 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 41 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 42 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 42 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 43 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 43 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 44 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 44 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 45 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 45 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 46 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 46 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 47 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 47 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 48 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 48 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 49 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 49 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 50 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 50 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 51 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 51 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 52 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 52 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 53 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 53 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 54 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 54 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 55 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 55 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 56 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 56 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 57 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 57 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 58 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 58 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 59 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 59 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 60 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 60 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 61 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 61 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 62 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 62 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 63 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 63 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 64 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 64 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 65 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 65 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 66 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 66 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 67 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 67 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 68 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 68 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 69 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 69 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 70 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 70 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 71 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 71 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 72 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 72 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 73 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 73 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 74 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 74 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 75 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 75 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 76 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 76 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 77 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 77 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 78 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 78 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 79 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 79 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 80 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 80 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 81 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 81 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 82 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 82 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 83 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 83 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 84 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 84 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 85 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 85 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 86 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 86 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 87 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 87 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 88 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 88 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 89 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 89 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 90 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 90 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 91 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 91 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 92 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 92 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 93 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 93 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 94 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 94 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 95 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 95 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 96 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 96 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 97 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 97 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 98 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 98 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 99 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 99 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 100 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 100 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 101 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 101 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 102 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 102 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 103 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 103 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 104 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 104 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 105 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 105 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 106 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 106 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 107 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 107 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 108 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 108 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 109 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 109 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 110 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 110 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 111 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 111 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 112 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 112 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 113 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 113 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 114 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 114 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 115 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 115 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 116 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 116 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 117 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 117 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 118 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 118 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 119 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 119 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 120 in B0101T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 120 in B0101T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0102T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =       0.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Epoch 1 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 1 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 2 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 2 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 3 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 3 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 4 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 4 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 5 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 5 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 6 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 6 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 7 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 7 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 8 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 8 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 9 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 9 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 10 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 10 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 11 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 11 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 12 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 12 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 13 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 13 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 14 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 14 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 15 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 15 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 16 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 16 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 17 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 17 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 18 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 18 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 19 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 19 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 20 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 20 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 21 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 21 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 22 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 22 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 23 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 23 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 24 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 24 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 25 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 25 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 26 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 26 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 27 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 27 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 28 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 28 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 29 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 29 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 30 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 30 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 31 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 31 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 32 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 32 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 33 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 33 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 34 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 34 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 35 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 35 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 36 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 36 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 37 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 37 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 38 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 38 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 39 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 39 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 40 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 40 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 41 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 41 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 42 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 42 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 43 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 43 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 44 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 44 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 45 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 45 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 46 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 46 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 47 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 47 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 48 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 48 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 49 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 49 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 50 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 50 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 51 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 51 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 52 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 52 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 53 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 53 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 54 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 54 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 55 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 55 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 56 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 56 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 57 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 57 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 58 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 58 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 59 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 59 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 60 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 60 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 61 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 61 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 62 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 62 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 63 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 63 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 64 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 64 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 65 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 65 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 66 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 66 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 67 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 67 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 68 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 68 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 69 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 69 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 70 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 70 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 71 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 71 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 72 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 72 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 73 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 73 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 74 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 74 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 75 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 75 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 76 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 76 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 77 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 77 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 78 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 78 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 79 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 79 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 80 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 80 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 81 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 81 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 82 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 82 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 83 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 83 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 84 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 84 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 85 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 85 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 86 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 86 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 87 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 87 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 88 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 88 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 89 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 89 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 90 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 90 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 91 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 91 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 92 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 92 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 93 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 93 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 94 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 94 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 95 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 95 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 96 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 96 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 97 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 97 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 98 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 98 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 99 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 99 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 100 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 100 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 101 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 101 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 102 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 102 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 103 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 103 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 104 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 104 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 105 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 105 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 106 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 106 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 107 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 107 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 108 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 108 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 109 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 109 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 110 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 110 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 111 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 111 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 112 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 112 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 113 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 113 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 114 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 114 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 115 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 115 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 116 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 116 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 117 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 117 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 118 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 118 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 119 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 119 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 120 in B0102T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 120 in B0102T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0103T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =       0.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# C:\Users\phili\AppData\Local\Temp\ipykernel_17548\4206150574.py:10: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   for i, epoch in enumerate(epochs.get_data()):
# C:\Users\phili\AppData\Local\Temp\ipykernel_17548\4206150574.py:10: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   for i, epoch in enumerate(epochs.get_data()):
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Epoch 1 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 1 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 2 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 2 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 3 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 3 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 4 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 4 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 5 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 5 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 6 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 6 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 7 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 7 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 8 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 8 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 9 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 9 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 10 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 10 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 11 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 11 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 12 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 12 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 13 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 13 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 14 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 14 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 15 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 15 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 16 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 16 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 17 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 17 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 18 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 18 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 19 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 19 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 20 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 20 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 21 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 21 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 22 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 22 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 23 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 23 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 24 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 24 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 25 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 25 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 26 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 26 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 27 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 27 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 28 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 28 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 29 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 29 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 30 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 30 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 31 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 31 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 32 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 32 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 33 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 33 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 34 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 34 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 35 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 35 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 36 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 36 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 37 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 37 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 38 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 38 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 39 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 39 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 40 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 40 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 41 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 41 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 42 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 42 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 43 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 43 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 44 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 44 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 45 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 45 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 46 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 46 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 47 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 47 in B0103T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 48 in B0103T-bcor-epo.fif time range: 0.0 to 4.0
# ...
# Epoch 63 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 64 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 64 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 65 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 65 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 66 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 66 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 67 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 67 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 68 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 68 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 69 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 69 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 70 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 70 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 71 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 71 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 72 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 72 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 73 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 73 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 74 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 74 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 75 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 75 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 76 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 76 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 77 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 77 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 78 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 78 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 79 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 79 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 80 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 80 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 81 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 81 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 82 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 82 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 83 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 83 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 84 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 84 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 85 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 85 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 86 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 86 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 87 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 87 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 88 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 88 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 89 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 89 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 90 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 90 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 91 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 91 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 92 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 92 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 93 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 93 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 94 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 94 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 95 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 95 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 96 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 96 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 97 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 97 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 98 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 98 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 99 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 99 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 100 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 100 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 101 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 101 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 102 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 102 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 103 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 103 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 104 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 104 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 105 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 105 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 106 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 106 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 107 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 107 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 108 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 108 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 109 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 109 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 110 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 110 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 111 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 111 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 112 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 112 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 113 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 113 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 114 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 114 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 115 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 115 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 116 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 116 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 117 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 117 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 118 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 118 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 119 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 119 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 120 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 120 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 121 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 121 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 122 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 122 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 123 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 123 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 124 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 124 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 125 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 125 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 126 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 126 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 127 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 127 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 128 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 128 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 129 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 129 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 130 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 130 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 131 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 131 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 132 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 132 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 133 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 133 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 134 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 134 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 135 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 135 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 136 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 136 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 137 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 137 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 138 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 138 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 139 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 139 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 140 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 140 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 141 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 141 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 142 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 142 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 143 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 143 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 144 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 144 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 145 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 145 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 146 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 146 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 147 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 147 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 148 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 148 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 149 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 149 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 150 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 150 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 151 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 151 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 152 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 152 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 153 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 153 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 154 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 154 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 155 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 155 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 156 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 156 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 157 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 157 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 158 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 158 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 159 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 159 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# Epoch 160 in B0903T-bcor-epo.fif time range: 0.0 to 4.0
# Epoch 160 in B0903T-bcor-epo.fif times: [0.    0.004 0.008 0.012 0.016 0.02  0.024 0.028 0.032 0.036] ...
# C:\Users\phili\AppData\Local\Temp\ipykernel_17548\4206150574.py:10: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   for i, epoch in enumerate(epochs.get_data()):

# %%
example_file = r'C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0101T-bcor-epo.fif'

epochs = mne.read_epochs(example_file)

epochs_info = epochs.info
print("Basic Epochs Info:")
print(epochs_info)
print(f"\nEvent types: {epochs.event_id}")
print(f"\nData shape (n_epochs, n_channels, n_times): {epochs.get_data().shape}")

epochs.plot(picks="all", n_epochs=3, scalings="auto", title="First 3 epochs", show=True)
# Out:
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0101T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Basic Epochs Info:
# <Info | 11 non-empty values
#  bads: []
#  ch_names: C3, Cz, C4, EOG:ch01, EOG:ch02, EOG:ch03
#  chs: 3 EEG, 3 EOG
#  custom_ref_applied: False
#  dig: 6 items (3 Cardinal, 3 EEG)
#  file_id: 4 items (dict)
#  highpass: 8.0 Hz
#  lowpass: 30.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 6
#  projs: Average EEG reference: on
#  sfreq: 250.0 Hz
# >
#
# Event types: {'Event_0': 0, 'Event_1': 1}
#
# Data shape (n_epochs, n_channels, n_times): (120, 6, 1051)
# C:\Users\phili\AppData\Local\Temp\ipykernel_17548\535137299.py:9: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   print(f"\nData shape (n_epochs, n_channels, n_times): {epochs.get_data().shape}")
# <MNEBrowseFigure size 1916x1032 with 4 Axes>
# Dropped 0 epochs:
# The following epochs were marked as bad and are dropped:
# []
# Channels marked as bad:
# none

# %% [markdown]
# On regroupe les epochs pour les feature extractions et le modeling: on creer donc un groupe avec tout les epochs, ceux de l'experience de screening et ceux de l'experience de neurofeedback

# %%
all_epochs_list = []

for file in os.listdir(baseline_epochs_data_dir):
    if file.endswith('-epo.fif'):  
        file_path = os.path.join(baseline_epochs_data_dir, file)

        epochs = mne.read_epochs(file_path)

        all_epochs_list.append(epochs)

all_epochs = mne.concatenate_epochs(all_epochs_list)

all_epochs.crop(tmin=0.0, tmax=4.0)

combined_epochs_file_path = os.path.join(baseline_epochs_data_dir, 'all_epochs_combined-epo.fif')

all_epochs.save(combined_epochs_file_path, overwrite=True)

print(f"All epochs have been concatenated, cropped, and saved to {combined_epochs_file_path}")
# Out:
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0101T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0102T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0103T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0201T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0202T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0203T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0301T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0302T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0303T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0401T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0402T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0403T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0501T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0502T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0503T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0601T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0602T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0603T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0701T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0702T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0703T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0801T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0802T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0803T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0901T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0902T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0903T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# C:\Users\phili\AppData\Local\Temp\ipykernel_17548\1197573501.py:16: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   all_epochs = mne.concatenate_epochs(all_epochs_list)
# Not setting metadata
# 3680 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# All epochs have been concatenated, cropped, and saved to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\all_epochs_combined-epo.fif

# %%
screening_epochs_list = []

for file in os.listdir(baseline_epochs_data_dir):
    # On selectionne tous les fichiers sauf ceux contenant 03T (NF)
    if file.endswith('-epo.fif') and '03T' not in file:
        file_path = os.path.join(baseline_epochs_data_dir, file)
        
        epochs = mne.read_epochs(file_path)
        
        screening_epochs_list.append(epochs)

screening_epochs = mne.concatenate_epochs(screening_epochs_list)

screening_epochs.crop(tmin=0.0, tmax=4.0)

screening_epochs_file_path = os.path.join(baseline_epochs_data_dir, 'screening_epochs_epo.fif')

screening_epochs.save(screening_epochs_file_path, overwrite=True)

print(f"Screened epochs saved to {screening_epochs_file_path}")
# Out:
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0101T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0102T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0201T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0202T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0301T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0302T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0401T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0402T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0501T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0502T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0601T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0602T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0701T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0702T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0801T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0802T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0901T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0902T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Not setting metadata
# 2240 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# C:\Users\phili\AppData\Local\Temp\ipykernel_17716\3787229874.py:12: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   screening_epochs = mne.concatenate_epochs(screening_epochs_list)
# Screened epochs saved to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\screening_epochs_epo.fif

# %%
nf_epochs_list = []

for file in os.listdir(baseline_epochs_data_dir):
    # On selectionne tous les fichiers contenant 03T (NF)
    if file.endswith('-epo.fif') and '03T' in file:
        file_path = os.path.join(baseline_epochs_data_dir, file)
        
        epochs = mne.read_epochs(file_path)
        
        nf_epochs_list.append(epochs)

nf_epochs = mne.concatenate_epochs(nf_epochs_list)

nf_epochs.crop(tmin=0.0, tmax=4.0)

nf_epochs_file_path = os.path.join(baseline_epochs_data_dir, 'nf_epochs_epo.fif')

nf_epochs.save(nf_epochs_file_path, overwrite=True)

print(f"Screened epochs saved to {nf_epochs_file_path}")
# Out:
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0103T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0203T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0303T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0403T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0503T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0603T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0703T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0803T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0903T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Not setting metadata
# 1440 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# C:\Users\phili\AppData\Local\Temp\ipykernel_17716\1102562227.py:12: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   nf_epochs = mne.concatenate_epochs(nf_epochs_list)
# Screened epochs saved to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\nf_epochs_epo.fif

# %%
all_epochs_list = []

for file in os.listdir(baseline_epochs_data_dir):
    if file.endswith('-epo.fif'):  
        file_path = os.path.join(baseline_epochs_data_dir, file)

        epochs = mne.read_epochs(file_path)

        all_epochs_list.append(epochs)

all_epochs = mne.concatenate_epochs(all_epochs_list)

full_epochs_file_path = os.path.join(baseline_epochs_data_dir, 'all_epochs_epo.fif')

all_epochs.save(full_epochs_file_path, overwrite=True)

print(f"All epochs have been concatenated, and saved to {full_epochs_file_path}")
# Out:
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0101T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0102T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0103T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0201T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0202T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0203T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0301T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0302T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0303T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0401T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0402T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0403T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0501T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0502T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0503T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0601T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0602T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0603T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0701T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0702T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0703T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0801T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0802T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0803T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0901T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0902T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Reading C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\B0903T-bcor-epo.fif ...
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 3) active
#     Found the data of interest:
#         t =    -200.00 ...    4000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# C:\Users\phili\AppData\Local\Temp\ipykernel_12460\3752200546.py:11: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   all_epochs = mne.concatenate_epochs(all_epochs_list)
# Not setting metadata
# 3680 matching events found
# Applying baseline correction (mode: mean)
# Created an SSP operator (subspace dimension = 1)
# All epochs have been concatenated, and saved to C:\Users\phili\EEG_project\EEG_proj_data\ucsd-neural-data-challenge\data\research\baseline_epochs_final\all_epochs_epo.fif
